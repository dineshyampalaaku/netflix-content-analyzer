# %%
import sys
import os

# Add project root to Python path
PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

print("Added to path:", PROJECT_ROOT)
# Out:
# Added to path: c:\Users\DINES\OneDrive\Desktop\netflix_analysis

# %%
import pandas as pd
from src.analysis import (
    load_data,
    genre_distribution,
    language_distribution,
    top_imdb_shows,
    top_binge_shows,
    recent_vs_old,
    avg_imdb_by_genre
)

# %%
df=load_data()

# %%
genre_distribution(df)
