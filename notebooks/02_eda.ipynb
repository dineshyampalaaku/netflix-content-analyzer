# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook summarizes exploratory insights such as:
# - Genre distribution
# - Language distribution
# - IMDb score trends
#
# Visualizations and reusable logic were modularized into `src/analysis.py` and `src/visualize.py`.
