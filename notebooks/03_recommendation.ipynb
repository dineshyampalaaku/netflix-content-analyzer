# %% [markdown]
# # Recommendation System Exploration
#
# This notebook documents the experimentation phase for the content-based recommendation system.
#
# The final ML logic, feature engineering, and similarity computation were implemented in:
# - `src/recommender.py`
#
# This notebook serves as documentation rather than production logic.
