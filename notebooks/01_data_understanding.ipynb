# %% [markdown]
# # Data Understanding
#
# This notebook documents the initial exploration of the Netflix dataset.
#
# Key steps performed:
# - Dataset inspection (shape, columns, data types)
# - Identification of missing values
# - Understanding feature distributions
#
# All data cleaning and transformations were later moved to the `src/cleaning.py` module.

# %%
import pandas as pd
df = pd.read_csv("../data/netflix_raw.csv")
df.head()
# Out:
#              title         genre  seasons  imdb  runtime language  year
# 0             Dark        Sci-Fi        3   8.8       55   German  2017
# 1  Stranger Things  Supernatural        4   8.7       51  English  2016
# 2      Money Heist      Thriller        5   8.2       47  Spanish  2017
# 3           Narcos         Crime        3   8.8       49  English  2015
# 4       Squid Game      Thriller        1   8.1       54   Korean  2021
